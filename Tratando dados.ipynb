# %% [markdown]
# # Procurando um banco de dados, segmentando e transformando em dicionário

# %% [markdown]
# Os dados foram retirados [Cálculo e Análise de Dieta para o Indivíduo (USP-2018)](https://edisciplinas.usp.br/mod/folder/view.php?id=2301181), mas utilizamos apenas a tab1.xls, afinal, queríamos informações básicas sobre os alimentos, contudo, os alimentos estavam misturados e tivemos que filtrar quais tipos de alimentos devemos colocarmos no dicionário.

# %% [markdown]
# Tivemos que transformar o excel em dataframe e por último em dicionário.

# %%
import pandas as pd

# Leia o arquivo Excel como um DataFrame
df_alimentos = pd.read_excel("Alimentos.xlsx")

# Exiba os DataFrame
print(df_alimentos)
# Out:
#                                        Alimentos  Energia(Kcal)  \
# 0                             Barra de chocolate         535.00
# 1    Geleia de frutas de qualquer marca ou sabor         278.00
# 2      Doce de frutas em pasta de qualquer sabor         291.30
# 3                              Pasta de amendoim         588.00
# 4                                       Goiabada         291.30
# ..                                           ...            ...
# 147                                Pão de queijo         363.00
# 148                                 Pão integral         247.00
# 149                         Biscoito de polvilho         436.72
# 150                            Waffer (biscoito)         430.32
# 151                               Bolo de banana         300.05
#
#      Proteínas (g)  Lipídios totais (g)  Carboidratos (g)  \
# 0             7.65                29.66             59.40
# 1             0.37                 0.07             68.86
# 2             0.77                 0.29             74.28
# 3            25.09                50.39             19.56
# 4             0.77                 0.29             74.28
# ..             ...                  ...               ...
# 147           5.10                24.60             34.20
# 148          12.95                 3.35             41.29
# 149           4.46                29.08             38.37
# 150           6.25                12.49             74.79
# 151           3.93                 9.07             52.14
#
#      Fibra alimentar total (g)  Densidade nutricional
# 0                         3.40               7.327383
# 1                         1.10              13.680216
# 2                         1.62              14.133539
# 3                         6.00               4.232823
# 4                         1.62              14.133539
# ..                         ...                    ...
# 147                       0.60               6.557851
# 148                       6.71              10.844130
# 149                       0.00               6.086394
# 150                       2.25              10.383668
# 151                       1.66              10.365939
#
# [152 rows x 7 columns]

# %%
#Agora precisamos transformar esses df em dicionários(com orientação por linhas);
dic_alimentos = df_alimentos.to_dict(orient='records')

print("Dicionário com orientação por linhas:")
print()
# Exiba os Dicionários
print(dic_alimentos)
# Out:
# Dicionário com orientação por linhas:
#
# [{'Alimentos': 'Barra de chocolate', 'Energia(Kcal)': 535.0, 'Proteínas (g)': 7.65, 'Lipídios totais (g)': 29.66, 'Carboidratos (g)': 59.4, 'Fibra alimentar total (g)': 3.4, 'Densidade nutricional': 7.327383177570094}, {'Alimentos': 'Geleia de frutas de qualquer marca ou sabor', 'Energia(Kcal)': 278.0, 'Proteínas (g)': 0.37, 'Lipídios totais (g)': 0.07, 'Carboidratos (g)': 68.86, 'Fibra alimentar total (g)': 1.1, 'Densidade nutricional': 13.680215827338131}, {'Alimentos': 'Doce de frutas em pasta de qualquer sabor', 'Energia(Kcal)': 291.3, 'Proteínas (g)': 0.77, 'Lipídios totais (g)': 0.29, 'Carboidratos (g)': 74.28, 'Fibra alimentar total (g)': 1.62, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Pasta de amendoim', 'Energia(Kcal)': 588.0, 'Proteínas (g)': 25.09, 'Lipídios totais (g)': 50.39, 'Carboidratos (g)': 19.56, 'Fibra alimentar total (g)': 6.0, 'Densidade nutricional': 4.232823129251701}, {'Alimentos': 'Goiabada', 'Energia(Kcal)': 291.3, 'Proteínas (g)': 0.77, 'Lipídios totais (g)': 0.29, 'Carboidratos (g)': 74.28, 'Fibra alimentar total (g)': 1.62, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Caju em pasta', 'Energia(Kcal)': 291.3, 'Proteínas (g)': 0.77, 'Lipídios totais (g)': 0.29, 'Carboidratos (g)': 74.28, 'Fibra alimentar total (g)': 1.62, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Mariola', 'Energia(Kcal)': 291.3, 'Proteínas (g)': 0.77, 'Lipídios totais (g)': 0.29, 'Carboidratos (g)': 74.28, 'Fibra alimentar total (g)': 1.62, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Mel', 'Energia(Kcal)': 304.0, 'Proteínas (g)': 0.3, 'Lipídios totais (g)': 0.0, 'Carboidratos (g)': 82.4, 'Fibra alimentar total (g)': 0.2, 'Densidade nutricional': 14.935855263157896}, {'Alimentos': 'Gelatina de qualquer sabor', 'Energia(Kcal)': 278.0, 'Proteínas (g)': 0.37, 'Lipídios totais (g)': 0.07, 'Carboidratos (g)': 68.86, 'Fibra alimentar total (g)': 1.1, 'Densidade nutricional': 13.680215827338131}, {'Alimentos': 'Fruta seca ou desidratada', 'Energia(Kcal)': 240.0, 'Proteínas (g)': 2.18, 'Lipídios totais (g)': 0.38, 'Carboidratos (g)': 63.88, 'Fibra alimentar total (g)': 7.1, 'Densidade nutricional': 15.037916666666666}, {'Alimentos': 'Cuscuz', 'Energia(Kcal)': 128.3, 'Proteínas (g)': 4.35, 'Lipídios totais (g)': 0.22, 'Carboidratos (g)': 26.42, 'Fibra alimentar total (g)': 1.71, 'Densidade nutricional': 12.265783320342946}, {'Alimentos': 'Paçoca', 'Energia(Kcal)': 472.17, 'Proteínas (g)': 10.35, 'Lipídios totais (g)': 21.53, 'Carboidratos (g)': 64.04, 'Fibra alimentar total (g)': 3.89, 'Densidade nutricional': 8.732765741152551}, {'Alimentos': 'Amendoim cozido', 'Energia(Kcal)': 318.0, 'Proteínas (g)': 13.5, 'Lipídios totais (g)': 22.01, 'Carboidratos (g)': 21.26, 'Fibra alimentar total (g)': 8.8, 'Densidade nutricional': 5.91493710691824}, {'Alimentos': 'Brigadeiro', 'Energia(Kcal)': 334.48, 'Proteínas (g)': 7.52, 'Lipídios totais (g)': 10.14, 'Carboidratos (g)': 54.86, 'Fibra alimentar total (g)': 0.23, 'Densidade nutricional': 10.041108586462569}, {'Alimentos': 'Doce à base de leite', 'Energia(Kcal)': 319.7, 'Proteínas (g)': 7.88, 'Lipídios totais (g)': 8.67, 'Carboidratos (g)': 54.18, 'Fibra alimentar total (g)': 0.0, 'Densidade nutricional': 10.343916171410699}, {'Alimentos': 'Pamonha', 'Energia(Kcal)': 171.0, 'Proteínas (g)': 2.6, 'Lipídios totais (g)': 4.8, 'Carboidratos (g)': 30.7, 'Fibra alimentar total (g)': 2.4, 'Densidade nutricional': 10.74561403508772}, {'Alimentos': 'Barra de cereais', 'Energia(Kcal)': 352.92, 'Proteínas (g)': 3.17, 'Lipídios totais (g)': 8.55, 'Carboidratos (g)': 69.44, 'Fibra alimentar total (g)': 2.32, 'Densidade nutricional': 11.44253655219313}, {'Alimentos': 'Frango em pedaços', 'Energia(Kcal)': 239.0, 'Proteínas (g)': 27.3, 'Lipídios totais (g)': 13.6, 'Carboidratos (g)': 0.0, 'Fibra alimentar total (g)': 0.0, 'Densidade nutricional': 3.709205020920502}, {'Alimentos': 'Peito de galinha ou frango', 'Energia(Kcal)': 173.0, 'Proteínas (g) ...

# %% [markdown]
# Agora temos o dicionário para trabalhar!

# %% [markdown]
# Vamos fazer manualmente outro dicionário com calorias e com densidade nutricional - Dn (que é o quanto de nutrientes essenciais presentes em um alimento em relação à quantidade total de calorias, e utilizamos pesos do [DietBox](https://blog.dietbox.me/macro-e-micronutrientes-como-calcular/) para fazer com que a Dn seja coerente e saudável!)
#
# OBS: os dados utilizados para calcular a Dn foram retirados do antigo dicionário
#
# Pesos utilizados: Carboidratos * 55, Proteínas * 25, Lipídios*15 e Fibras*5
# Fórmula usada: Dn = (Carboidratos * 55 + Proteínas * 25 + Lipídios*15 + Fibras*5)/Calorias

# %%
df_alimentosC = pd.read_excel("Alimentos - Calorias.xlsx")
dic_alimentosC = df_alimentosC.to_dict(orient='records')
print(dic_alimentosC)
# Out:
# [{'Alimentos': 'Barra de chocolate', 'Energia(Kcal)': 535.0, 'Densidade nutricional': 7.327383177570094}, {'Alimentos': 'Geleia de frutas de qualquer marca ou sabor', 'Energia(Kcal)': 278.0, 'Densidade nutricional': 13.680215827338131}, {'Alimentos': 'Doce de frutas em pasta de qualquer sabor', 'Energia(Kcal)': 291.3, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Pasta de amendoim', 'Energia(Kcal)': 588.0, 'Densidade nutricional': 4.232823129251701}, {'Alimentos': 'Goiabada', 'Energia(Kcal)': 291.3, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Caju em pasta', 'Energia(Kcal)': 291.3, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Mariola', 'Energia(Kcal)': 291.3, 'Densidade nutricional': 14.133539306556814}, {'Alimentos': 'Mel', 'Energia(Kcal)': 304.0, 'Densidade nutricional': 14.935855263157896}, {'Alimentos': 'Gelatina de qualquer sabor', 'Energia(Kcal)': 278.0, 'Densidade nutricional': 13.680215827338131}, {'Alimentos': 'Fruta seca ou desidratada', 'Energia(Kcal)': 240.0, 'Densidade nutricional': 15.037916666666666}, {'Alimentos': 'Cuscuz', 'Energia(Kcal)': 128.3, 'Densidade nutricional': 12.265783320342946}, {'Alimentos': 'Paçoca', 'Energia(Kcal)': 472.17, 'Densidade nutricional': 8.732765741152551}, {'Alimentos': 'Amendoim cozido', 'Energia(Kcal)': 318.0, 'Densidade nutricional': 5.91493710691824}, {'Alimentos': 'Brigadeiro', 'Energia(Kcal)': 334.48, 'Densidade nutricional': 10.041108586462569}, {'Alimentos': 'Doce à base de leite', 'Energia(Kcal)': 319.7, 'Densidade nutricional': 10.343916171410699}, {'Alimentos': 'Pamonha', 'Energia(Kcal)': 171.0, 'Densidade nutricional': 10.74561403508772}, {'Alimentos': 'Barra de cereais', 'Energia(Kcal)': 352.92, 'Densidade nutricional': 11.44253655219313}, {'Alimentos': 'Frango em pedaços', 'Energia(Kcal)': 239.0, 'Densidade nutricional': 3.709205020920502}, {'Alimentos': 'Peito de galinha ou frango', 'Energia(Kcal)': 173.0, 'Densidade nutricional': 4.857803468208092}, {'Alimentos': 'Filé de frango', 'Energia(Kcal)': 173.0, 'Densidade nutricional': 4.857803468208092}, {'Alimentos': 'Canja', 'Energia(Kcal)': 31.47, 'Densidade nutricional': 8.166507785192247}, {'Alimentos': 'Nuggets de frango', 'Energia(Kcal)': 273.02, 'Densidade nutricional': 5.5625961468024325}, {'Alimentos': 'Steak de frango', 'Energia(Kcal)': 211.84, 'Densidade nutricional': 5.089690332326284}, {'Alimentos': 'Codorna', 'Energia(Kcal)': 269.66, 'Densidade nutricional': 3.819253875250315}, {'Alimentos': 'Pé e asa de galinha ou frango', 'Energia(Kcal)': 290.0, 'Densidade nutricional': 3.3220689655172415}, {'Alimentos': 'Ovo de galinha', 'Energia(Kcal)': 155.0, 'Densidade nutricional': 3.453225806451613}, {'Alimentos': 'Ovo de codorna', 'Energia(Kcal)': 155.0, 'Densidade nutricional': 3.453225806451613}, {'Alimentos': 'Contrafilé', 'Energia(Kcal)': 204.0, 'Densidade nutricional': 4.420343137254902}, {'Alimentos': 'Alcatra', 'Energia(Kcal)': 204.0, 'Densidade nutricional': 4.420343137254902}, {'Alimentos': 'Maminha', 'Energia(Kcal)': 199.0, 'Densidade nutricional': 4.914572864321608}, {'Alimentos': 'Picanha', 'Energia(Kcal)': 204.0, 'Densidade nutricional': 4.420343137254902}, {'Alimentos': 'Patinho', 'Energia(Kcal)': 199.0, 'Densidade nutricional': 4.914572864321608}, {'Alimentos': 'Acém', 'Energia(Kcal)': 242.0, 'Densidade nutricional': 3.4578512396694214}, {'Alimentos': 'Fraldinha (capa de filé)', 'Energia(Kcal)': 199.0, 'Densidade nutricional': 4.914572864321608}, {'Alimentos': 'Costela bovina', 'Energia(Kcal)': 365.0, 'Densidade nutricional': 2.7721917808219176}, {'Alimentos': 'Carne suína', 'Energia(Kcal)': 289.0, 'Densidade nutricional': 3.2332179930795846}, {'Alimentos': 'Carne moída', 'Energia(Kcal)': 214.0, 'Densidade nutricional': 3.8878504672897196}, {'Alimentos': 'Pernil', 'Energia(Kcal)': 289.0, 'Densidade nutricional': 3.2332179930795846}, {'Alimentos': 'Carne bovina', 'Energia(Kcal)': 242.0, 'Densidade nutricional': 3.4578512396694214}, {'Alimentos': 'Peixe de ...

# %%
dicionario_final = {}
for item in dic_alimentosC:
    alimento = item['Alimentos']
    calorias = item['Energia(Kcal)']
    Dn = item['Densidade nutricional']
    dicionario_final[alimento] = {'calorias': calorias, 'Dn': Dn}

print(dicionario_final)
# Out:
# {'Barra de chocolate': {'calorias': 535.0, 'Dn': 7.327383177570094}, 'Geleia de frutas de qualquer marca ou sabor': {'calorias': 278.0, 'Dn': 13.680215827338131}, 'Doce de frutas em pasta de qualquer sabor': {'calorias': 291.3, 'Dn': 14.133539306556814}, 'Pasta de amendoim': {'calorias': 588.0, 'Dn': 4.232823129251701}, 'Goiabada': {'calorias': 291.3, 'Dn': 14.133539306556814}, 'Caju em pasta': {'calorias': 291.3, 'Dn': 14.133539306556814}, 'Mariola': {'calorias': 291.3, 'Dn': 14.133539306556814}, 'Mel': {'calorias': 304.0, 'Dn': 14.935855263157896}, 'Gelatina de qualquer sabor': {'calorias': 278.0, 'Dn': 13.680215827338131}, 'Fruta seca ou desidratada': {'calorias': 240.0, 'Dn': 15.037916666666666}, 'Cuscuz': {'calorias': 128.3, 'Dn': 12.265783320342946}, 'Paçoca': {'calorias': 472.17, 'Dn': 8.732765741152551}, 'Amendoim cozido': {'calorias': 318.0, 'Dn': 5.91493710691824}, 'Brigadeiro': {'calorias': 334.48, 'Dn': 10.041108586462569}, 'Doce à base de leite': {'calorias': 319.7, 'Dn': 10.343916171410699}, 'Pamonha': {'calorias': 171.0, 'Dn': 10.74561403508772}, 'Barra de cereais': {'calorias': 352.92, 'Dn': 11.44253655219313}, 'Frango em pedaços': {'calorias': 239.0, 'Dn': 3.709205020920502}, 'Peito de galinha ou frango': {'calorias': 173.0, 'Dn': 4.857803468208092}, 'Filé de frango': {'calorias': 173.0, 'Dn': 4.857803468208092}, 'Canja': {'calorias': 31.47, 'Dn': 8.166507785192247}, 'Nuggets de frango': {'calorias': 273.02, 'Dn': 5.5625961468024325}, 'Steak de frango': {'calorias': 211.84, 'Dn': 5.089690332326284}, 'Codorna': {'calorias': 269.66, 'Dn': 3.819253875250315}, 'Pé e asa de galinha ou frango': {'calorias': 290.0, 'Dn': 3.3220689655172415}, 'Ovo de galinha': {'calorias': 155.0, 'Dn': 3.453225806451613}, 'Ovo de codorna': {'calorias': 155.0, 'Dn': 3.453225806451613}, 'Contrafilé': {'calorias': 204.0, 'Dn': 4.420343137254902}, 'Alcatra': {'calorias': 204.0, 'Dn': 4.420343137254902}, 'Maminha': {'calorias': 199.0, 'Dn': 4.914572864321608}, 'Picanha': {'calorias': 204.0, 'Dn': 4.420343137254902}, 'Patinho': {'calorias': 199.0, 'Dn': 4.914572864321608}, 'Acém': {'calorias': 242.0, 'Dn': 3.4578512396694214}, 'Fraldinha (capa de filé)': {'calorias': 199.0, 'Dn': 4.914572864321608}, 'Costela bovina': {'calorias': 365.0, 'Dn': 2.7721917808219176}, 'Carne suína': {'calorias': 289.0, 'Dn': 3.2332179930795846}, 'Carne moída': {'calorias': 214.0, 'Dn': 3.8878504672897196}, 'Pernil': {'calorias': 289.0, 'Dn': 3.2332179930795846}, 'Carne bovina': {'calorias': 242.0, 'Dn': 3.4578512396694214}, 'Peixe de mar (inteiro, em posta, em filé, etc.)': {'calorias': 117.0, 'Dn': 5.358547008547009}, 'Peixe de água doce (inteiro, em posta, em filé, etc.)': {'calorias': 117.0, 'Dn': 5.358547008547009}, 'Arroz (polido, parboilizado, agulha, agulhinha, etc.)': {'calorias': 135.62, 'Dn': 11.91675269134346}, 'Arroz integral': {'calorias': 130.95, 'Dn': 11.553646429935089}, 'Milho (em grão)': {'calorias': 160.14, 'Dn': 9.947545897339829}, 'Ervilha em grão': {'calorias': 109.09, 'Dn': 9.781373178109819}, 'Grão de bico': {'calorias': 188.48, 'Dn': 9.804753820033957}, 'Soja em grão': {'calorias': 196.34, 'Dn': 5.940205765508811}, 'Feijão (preto, mulatinho, roxo, rosinha, etc.)': {'calorias': 97.41, 'Dn': 10.466071245252028}, 'Pipoca\xa0 light': {'calorias': 445.94, 'Dn': 9.335448715073777}, 'Azeitona': {'calorias': 145.0, 'Dn': 3.3327586206896553}, 'Milho verde em conserva': {'calorias': 81.0, 'Dn': 13.869753086419754}, 'Palmito em conserva': {'calorias': 28.0, 'Dn': 12.085714285714287}, 'Yakissoba': {'calorias': 527.0, 'Dn': 7.315180265654649}, 'Feijoada': {'calorias': 181.59, 'Dn': 7.463241367916736}, 'Atum em conserva': {'calorias': 198.0, 'Dn': 4.3}, 'Strogonoff': {'calorias': 147.68, 'Dn': 4.650257313109425}, 'Mucilon': {'calorias': 78.24, 'Dn': 8.723798568507158}, 'Mingau de arroz': {'calorias': 148.32, 'Dn': 10.65163160733549}, 'Croquinhos de arroz': {'calorias': 387.0, 'Dn': 12.270284237726099}, 'Farinha de aveia': {'calorias': 384.0, 'Dn': 11. ...

# %% [markdown]
# Pronto temos um dicionário com as calorias e a densidade nutricional de cada alimento selecionado.
